# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder

# %%
otpt_data = pd.read_csv(r"D:\Projects\Machine_Learning\Loan_Default_Prediction\Loan\Sample Prediction Dataset.csv")
test_data = pd.read_csv(r"D:\Projects\Machine_Learning\Loan_Default_Prediction\Loan\Test Data.csv")

# %%
test_data
# Out:
#           ID   Income  Age  Experience Married/Single House_Ownership  \
# 0          1  7393090   59          19         single          rented
# 1          2  1215004   25           5         single          rented
# 2          3  8901342   50          12         single          rented
# 3          4  1944421   49           9        married          rented
# 4          5    13429   25          18         single          rented
# ...      ...      ...  ...         ...            ...             ...
# 27995  27996  9955481   57          13         single          rented
# 27996  27997  2917765   47           9         single          rented
# 27997  27998  8082415   24           5         single          rented
# 27998  27999  9474180   51          13         single          rented
# 27999  28000  9250350   42           9         single          rented
#
#       Car_Ownership            Profession            CITY           STATE  \
# ...

# %%
otpt_data
# Out:
#           id  risk_flag
# 0          1          0
# 1          2          0
# 2          3          1
# 3          4          0
# 4          5          0
# ...      ...        ...
# 27995  27996          0
# 27996  27997          1
# 27997  27998          0
# 27998  27999          0
# 27999  28000          0
#
# [28000 rows x 2 columns]

# %%
df1 = pd.merge(otpt_data, test_data, left_on='id', right_on='ID')

# %%
df1.drop(columns=['id'], inplace=True)

# %%
df1
# Out:
#        risk_flag     ID   Income  Age  Experience Married/Single  \
# 0              0      1  7393090   59          19         single
# 1              0      2  1215004   25           5         single
# 2              1      3  8901342   50          12         single
# 3              0      4  1944421   49           9        married
# 4              0      5    13429   25          18         single
# ...          ...    ...      ...  ...         ...            ...
# 27995          0  27996  9955481   57          13         single
# 27996          1  27997  2917765   47           9         single
# 27997          0  27998  8082415   24           5         single
# 27998          0  27999  9474180   51          13         single
# 27999          0  28000  9250350   42           9         single
#
#       House_Ownership Car_Ownership            Profession            CITY  \
# 0              rented            no             Geologist           Malda
# ...

# %%
plt.hist(df1['House_Ownership'])
plt.show()

# %%
df1['risk_flag'].corr(df1['Age'])
# Out:
# 0.004922001481736996
